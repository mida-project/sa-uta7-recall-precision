# %%
# %matplotlib inline

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from techniques.confusions import confMatrixHeatmap
from structures.counters import acc001, acc002

arr_count_class_001 = acc001
arr_count_class_002 = acc002

confMatrixHeatmap(arr_count_class_001)
confMatrixHeatmap(arr_count_class_002)
