# %%
# %matplotlib inline

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from techniques.precisionHeatmaps import precHeatmap
from structures.counters import acp

arr_count_prec = acp

precHeatmap(arr_count_prec)
# Out:
# [[ 0  1  1  1  1  1]
#  [ 1 29  1  1  1  1]
#  [ 1 12 31  1  1  1]
#  [ 1  0  4  1  1  1]
#  [ 1  1  1  1 11  1]
#  [ 1  0  0  0  1 24]]
